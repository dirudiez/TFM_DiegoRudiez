# %% [markdown]
# <a href="https://colab.research.google.com/github/dirudiez/TFM_DiegoRudiez/blob/main/ClasificadorBinario_inception_v3_BalanceoSklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://notebooks.githubusercontent.com/view/ipynb?browser=chrome&color_mode=auto&commit=550a08945499aa9ff119547dc4aefbbeec0e5dbf&device=unknown&enc_url=&logged_in=false&nwo=walkwithfastai%2Fwalkwithfastai.github.io&path=nbs%2F02_vision.external.timm.ipynb&platform=android&repository_id=295613905&repository_type=Repository&version=98

# %% [markdown]
# En este cuaderno probaremos la arquitectura efficientnet_b3 para ver si obtenemos unos mejores resultados.

# %% [markdown]
# ## Efficientnet_b3 con Balanceo Sklearn

# %%
# !pip install fastai -Uq
# !pip install timm

#Reiniciamos el entorno de ejecución automáticamente
import IPython
IPython.Application.instance().kernel.do_shutdown(True)
# Out:
#      |████████████████████████████████| 197 kB 7.2 MB/s
#      |████████████████████████████████| 60 kB 8.9 MB/s
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 7.8 MB/s
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Installing collected packages: timm
# Successfully installed timm-0.5.4
# {'restart': True, 'status': 'ok'}

# %%
from fastai.vision.all import *

# %%
# !pip install wwf
# !pip install nbdev

# %%
from wwf.utils import *
from wwf.vision.timm import *

# %% [markdown]
# ## Dataset

# %% [markdown]
# En este caso estamos usando el dataset que ha sido preprocesados mediante el método de recorte

# %%
# !wget https://www.dropbox.com/s/o1eaoae59qgdo4i/Training_Set_Pre.zip?dl=0 --no-verbose -O train.zip
# !wget https://www.dropbox.com/s/5od5cac9xhxlcwu/Test_Set_Pre.zip?dl=0 --no-verbose -O test.zip
# !wget https://www.dropbox.com/s/gjz445xm4oddfus/Evaluation_Set_Pre.zip?dl=0 --no-verbose -O val.zip
# Out:
# 2022-06-17 07:28:58 URL:https://uc817725eeabccd07ced3bf8c72b.dl.dropboxusercontent.com/cd/0/inline2/BnUTVdBEWFDu-R6aLK0onWGeqlW3QevExcSMP-zjuxwSu7BnsE1wDtcGITddaavzXFbPTTuuSZJIcVQAUWkNqNs7WGfxPnbTc7Tw1HXd4AKE8NHG8l6Nb9oUhUHB-Js8mk7uLnWRlampFbn2X8UJ97vtlEwfbFQNetveHz65HuUSqo0nOyqchju0eXjxyvo0OL8TbUOQ27lQLydW1CogX9b80dQSWKvh9lGWO2NEcYtp7PRXnP3PJyvu1UcOW0QQ4DtRJIx2bZJBHnQ5yZS6ZzQiIgXC38KEqW-J-GYrz09MeklzFIURgGKlhLjY2oXv_Anpyv0DZY-beZ_5nGM6iFX2bjmQyw5Eu45BAAZq-d-FOWX89IXC6IvPx8AHdujuDZdrFkgyS5Z2rw0B1igTHkogqMvJcRaOyC85u_tuS6amAA/file [138777773/138777773] -> "train.zip" [1]
# 2022-06-17 07:29:00 URL:https://uc8442aefb08846e6f7020c563af.dl.dropboxusercontent.com/cd/0/inline2/BnUB7QnkGB68zWfTVeSPmPemYDwoExCkZy-HTd5UB-PUkY_ubq_12yTLlZbYnVf6HxXdQqcQaFwjPaoD49t0SR7A_aI3kn2bR_Us9t17ilRfQILRUFdjqop9ANuc3WSmQOpVMBlrImbnrESRomNa84SG4XRMB6MsurZZRJpv4k_PoUIb6GrNfv9qz2y5w4E_S2mtmW2A4DPuEnDfiOZF5UMVw2XzXO7KMIHZmncVx74zKX8ijmTZjqDQUDTgUCF49z7l7NulQhcloIzej0Y2z_3_kZiwlxD_r76S2cPTQ1LPZc3HukPCkL-2tkmRtgyDOvUQ2xWBCd0x7bkNFaoY-QtFKJ9jPTnYUsGGHUTX77pz425c54VPiQpAACO7lQDOSeWTUWeMsb12ztw_IqxjqUKXF7EoCXKXZqdK0goSUFKKXg/file [47874561/47874561] -> "test.zip" [1]
# 2022-06-17 07:29:02 URL:https://ucdf731b604914f3a9fec424d489.dl.dropboxusercontent.com/cd/0/inline2/BnV-tog4m04NpmtcxHaVOlN0VlCQz6zWtiJU6TblQg5OarpO9lfsP0XoIXcgLTM7wg0j9O5paUxISaJPFipXtn2NDryQ708wY2vnu4AlZ13xMUuc_jyQlmgBaW61RP0Y_39bxA13MyKgveIQUp4N85G-1cmqrBdSJArT-GHzpj7Yg46QqwwC0MzqPU8lEW2rP8o7O1-AxUTWv7sZkiqJ3qaJGjTDtJ-HfPRxBeNmDCKenurDtuO_s1wOYXFfnuUW8qZIqiPDNag-0cxTETx8d6OM0GMjX45GqhOsIgKf-VicsHAzoO09_vsCDCuB8GoCAE_IXftCiJ1OkslyXcTP7zvBVKPwZr1txqhk9hLDlZVXopf6J4Esm5e6A_rrpTSUKNG2Kd1D-Q6GFb_1xNjdUI44LSLVUZrlTk3D9YtHx60Y0A/file [47378914/47378914] -> "val.zip" [1]

# %%
# !rm -rvf Training_Set_Pre
# !unzip -qq train.zip #-qq no verbose
# !unzip -qq test.zip
# !unzip -qq val.zip

# %%
#Método para crear estructura de directorios
def crearEstructura(nombreDataset, clases):
  # !mkdir "$nombreDataset"
  # !mkdir "$nombreDataset"/test
  # !mkdir "$nombreDataset"/train
  # !mkdir "$nombreDataset"/val
  for x in clases:
    # !mkdir "$nombreDataset"/train/"$x"
    # !mkdir "$nombreDataset"/test/"$x"
    # !mkdir "$nombreDataset"/val/"$x"

# %%
crearEstructura('dataset', ['normal', 'enfermedad'])

# %%
trainPath = Path('Training_Set_Pre/')
testPath  = Path('Test_Set_Pre/')
valPath  =  Path('Evaluation_Set_Pre/')

# %%
df_train = pd.read_csv(str(trainPath) + '/train.csv')
df_test = pd.read_csv(str(testPath) + '/test.csv')
df_val = pd.read_csv(str(valPath) + '/val.csv')

# %% [markdown]
# #### Mover imágenes:

# %%
import shutil
import uuid

def moverImg(df, pathO, pathD):
  for id, enf in zip(df['ID'], df['Disease_Risk']):
    if(int(enf)==0):
        shutil.copy(pathO + '/' + str(id) + '.png', pathD + '/normal/' + str(uuid.uuid1()) + '.png')
    else:
        shutil.copy(pathO + str(id) + '.png', pathD + '/enfermedad/' + str(uuid.uuid1()) + '.png')

# %%
path = Path('dataset')

# %% [markdown]
# ## Balanceo

# %%
from sklearn.utils import resample

# %%
df_majority = df_train[df_train.Disease_Risk==1] #mayoria de instacias con enfermedad respecto a sin ella.
df_minority = df_train[df_train.Disease_Risk==0]

# %%
# Aumentar la muestra de la clase minoritaria
# Aumentar la muestra de la clase minoritaria
df_minority_upsampled = resample(df_minority,
                                 replace=True,     # muestra con remplazamiento
                                 n_samples=960,    # número de muestras de la clase mayoritaria
                                 random_state=42) # semilla para que los resultados sean reproducibles

# Disminuir la clase mayoritaria
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    # muestra sin remplazamiento
                                 n_samples=960,     # número de muestras de la clase minoritaria
                                 random_state=42) # semilla para que los datos sean reproducibles
                               
# Combinar el nuevo grupo con el grupo original mayoritario
df_train = pd.concat([df_majority_downsampled, df_minority_upsampled])
df_train = df_train.reset_index(drop=True)

# Mostrar el número de instancias en cada clase
df_train.Disease_Risk.value_counts()
# Out:
# 1    960
# 0    960
# Name: Disease_Risk, dtype: int64

# %%
len(df_minority_upsampled.ID.unique())
# Out:
# 359

# %% [markdown]
# **Una vez que tenemos el dataframe balanceado comenzamos a copiar las imágenes a las carpetas que corresponda.**

# %%
moverImg(df_train, str(trainPath) + '/Training/', str(path)  + '/train')
moverImg(df_test, str(testPath) + '/Test/', str(path)  + '/test')
moverImg(df_val, str(valPath) + '/Validation/', str(path)  + '/val')

# %% [markdown]
# ## Cargando el dataset

# %%
db = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=GrandparentSplitter(train_name='train', valid_name='val'),
                 get_y=parent_label,
                 item_tfms = Resize(256),
                 batch_tfms=aug_transforms(size=128,min_scale=0.75))

# %%
dls = db.dataloaders(path,bs=128)

# %%
dls.show_batch()

# %%
callbacks = [
    ShowGraphCallback(),
    EarlyStoppingCallback(patience=20),
    SaveModelCallback()  
]

# %%
learn = timm_learner(dls, 'inception_v3', metrics=[error_rate, accuracy], cbs=callbacks)

# %%
learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(minimum=0.002754228748381138, steep=9.120108734350652e-05, valley=0.0010000000474974513, slide=0.02290867641568184)

# %% [markdown]
# ## Entrenamos el modelo

# %%
learn.fine_tune(60,base_lr=1e-5)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.247145</td>
#       <td>0.835929</td>
#       <td>0.454688</td>
#       <td>0.545313</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.835928738117218.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.203073</td>
#       <td>0.842821</td>
#       <td>0.471875</td>
#       <td>0.528125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.187622</td>
#       <td>0.860119</td>
#       <td>0.503125</td>
#       <td>0.496875</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.217725</td>
#       <td>0.903601</td>
#       <td>0.523438</td>
#       <td>0.476562</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.235134</td>
#       <td>0.875440</td>
#       <td>0.507812</td>
#       <td>0.492188</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.222110</td>
#       <td>0.876839</td>
#       <td>0.512500</td>
#       <td>0.487500</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.231643</td>
#       <td>0.849853</td>
#       <td>0.521875</td>
#       <td>0.478125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1
td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.955249</td>
#       <td>0.593025</td>
#       <td>0.312500</td>
#       <td>0.687500</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.946375</td>
#       <td>0.607872</td>
#       <td>0.323438</td>
#       <td>0.676562</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.938237</td>
#       <td>0.592451</td>
#       <td>0.303125</td>
#       <td>0.696875</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.946922</td>
#       <td>0.584110</td>
#       <td>0.292188</td>
#       <td>0.707812</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.936591</td>
#       <td>0.596284</td>
#       <td>0.296875</td>
#       <td>0.703125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.940401</td>
#       <td>0.573175</td>
#       <td>0.296875</td>
#       <td>0.703125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.939861</td>
#       <td>0.575476</td>
#       <td>0.298438</td>
#       <td>0.701563</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.950108</td>
#       <td>0.576616</td>
#       <td>0.296875</td>
#       <td>0.703125</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.953054</td>
#       <td>0.569666</td>
#       <td>0.295312</td>
#       <td>0.704687</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.942738</td>
#       <td>0.586008</td>
#       <td>0.303125</td>
#       <td>0.696875</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.939106</td>
# Better model found at epoch 0 with valid_loss value: 0.8428205251693726.
# Better model found at epoch 6 with valid_loss value: 0.8350674510002136.
# Better model found at epoch 8 with valid_loss value: 0.8096081614494324.
# Better model found at epoch 10 with valid_loss value: 0.7782480120658875.
# Better model found at epoch 11 with valid_loss value: 0.7610524296760559.
# Better model found at epoch 12 with valid_loss value: 0.752510666847229.
# Better model found at epoch 13 with valid_loss value: 0.738735020160675.
# Better model found at epoch 14 with valid_loss value: 0.6801510453224182.
# Better model found at epoch 18 with valid_loss value: 0.6717306971549988.
# Better model found at epoch 19 with valid_loss value: 0.6398319602012634.
# Better model found at epoch 23 with valid_loss value: 0.6386924982070923.
# Better model found at epoch 24 with valid_loss value: 0.6362400650978088.
# Better model found at epoch 26 with valid_loss value: 0.6301871538162231.
# Better model found at epoch 27 with valid_loss value: 0.615298867225647.
# Better model found at epoch 32 with valid_loss value: 0.6034413576126099.
# Better model found at epoch 36 with valid_loss value: 0.6033405065536499.
# Better model found at epoch 40 with valid_loss value: 0.5930247902870178.
# Better model found at epoch 42 with valid_loss value: 0.5924514532089233.
# Better model found at epoch 43 with valid_loss value: 0.5841099619865417.
# Better model found at epoch 45 with valid_loss value: 0.5731748938560486.
# Better model found at epoch 48 with valid_loss value: 0.569665789604187.
# Better model found at epoch 56 with valid_loss value: 0.5607625842094421.

# %%
learn.show_results(max_n=12, figsize=(7,8))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ## Evaluando el Modelo

# %%
dbTest = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=GrandparentSplitter(valid_name='test'),
                 get_y=parent_label,
                 item_tfms = Resize(256),
                 batch_tfms=aug_transforms(size=128,min_scale=0.75))
dlsTest = dbTest.dataloaders(path,bs=128)

# %%
learn.dls = dlsTest

# %% [markdown]
# Obtenemos una accuracy de 0.78.

# %%
learn.validate()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Better model found at epoch 0 with valid_loss value: 0.26875001192092896.
# (#3) [0.5683714151382446,0.26875001192092896,0.731249988079071]

# %% [markdown]
# Exportamos el modelo:

# %%
learn.to_fp32()
learn.export('modeloBinario_inception_v3_BalanceoSklean.pkl')
