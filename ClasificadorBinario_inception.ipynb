# %% [markdown]
# <a href="https://colab.research.google.com/github/dirudiez/TFM_DiegoRudiez/blob/main/ClasificadorBinario_inception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://notebooks.githubusercontent.com/view/ipynb?browser=chrome&color_mode=auto&commit=550a08945499aa9ff119547dc4aefbbeec0e5dbf&device=unknown&enc_url=&logged_in=false&nwo=walkwithfastai%2Fwalkwithfastai.github.io&path=nbs%2F02_vision.external.timm.ipynb&platform=android&repository_id=295613905&repository_type=Repository&version=98

# %% [markdown]
# En este cuaderno probaremos la arquitectura efficientnet_b3 para ver si obtenemos unos mejores resultados.

# %% [markdown]
# ## Efficientnet_b3

# %%
# !pip install fastai -Uq
# !pip install timm

#Reiniciamos el entorno de ejecución automáticamente
import IPython
IPython.Application.instance().kernel.do_shutdown(True)
# Out:
#      |████████████████████████████████| 197 kB 35.1 MB/s
#      |████████████████████████████████| 60 kB 8.8 MB/s
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 14.7 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2022.5.18.1)
# Installing collected packages: timm
# Successfully installed timm-0.5.4
# {'restart': True, 'status': 'ok'}

# %%
from fastai.vision.all import *

# %%
# !pip install wwf
# !pip install nbdev

# %%
from wwf.utils import *
from wwf.vision.timm import *
import timm

# %%
timm.list_models('*inception*')[:10]
# Out:
# ['adv_inception_v3',
#  'ens_adv_inception_resnet_v2',
#  'gluon_inception_v3',
#  'inception_resnet_v2',
#  'inception_v3',
#  'inception_v4',
#  'tf_inception_v3']

# %% [markdown]
# ## Dataset

# %% [markdown]
# En este caso estamos usando el dataset que ha sido preprocesados mediante el método de recorte

# %%
# !wget https://www.dropbox.com/s/o1eaoae59qgdo4i/Training_Set_Pre.zip?dl=0 --no-verbose -O train.zip
# !wget https://www.dropbox.com/s/5od5cac9xhxlcwu/Test_Set_Pre.zip?dl=0 --no-verbose -O test.zip
# !wget https://www.dropbox.com/s/gjz445xm4oddfus/Evaluation_Set_Pre.zip?dl=0 --no-verbose -O val.zip
# Out:
# 2022-06-16 07:52:50 URL:https://uce7574707ed12c164ef6bc50d20.dl.dropboxusercontent.com/cd/0/inline2/BnReaXAloyTnXolMhcWTn8zg9qIABFnrSvmFxfHb6OrnR0s2TGLk306S1FFKAvxRjD2E-VK5cdVKHafGQpThzP4vHroIRlHu9fliS2ZHn66dozYo3k01u3alOUayVMNaoQKhiDnur0nsgpblMDMZ4eHNZM69bEDqJ7nwxyw9TiK1wm6Zkw7eq3xjXuYU7ksOQcP1mX7TMefqAuHRrnmU3XRc5tzUvgdouJkUvhzI96K3RfqTRhfnzhUgjHAa-eB-F2hCT4kcID1v8kuQBRh_wdc9Rs-30tSu7K4GGrAGuOroUJOOsfyCkb6FS-3ert3f1DyGQ8bX0TLujcShqXROo3Dxzgp0ALECWYfnlZZXr8qqD4NjzW4EoINMlBdZfklIM6qbGcc9fgXYPZevDesOONAELiY1-mD3HyQHB786jl5iNQ/file [138777773/138777773] -> "train.zip" [1]
# 2022-06-16 07:52:56 URL:https://uc657cd19b36610cd99fa03db651.dl.dropboxusercontent.com/cd/0/inline2/BnQvEc0PX6feZtKs43LC8oNwY90YZqo1dDlgcfswWc-7Z-QKINpCTSmn5mzaz37Kh7FUL0wXkbnYmR9Xd_zE5mlbJHgGLyLj2EC6F8Fwc9g8_z3BhE-P4qGbpXLfvUoGXGSxd3cHd779JaboMLEbhH24UMd8fXVPuy0yoDdT67iHm4zuxLdYDzEPIFYEVgP9UxgCwF1ePPCtKatQ4VqQL65C-0KIBJmrPfbb4vnUmRIYaUQ9mr4ftzav8c_vnv-c3or33zUk-WkX4sZ9-frA25exrmYijzpvVTcmcbEsJSUDMnDuYTr4Gvk291463TMmkykQe8yZdtOiHs8DAMG5-HKOCWuHKcJhB-ZNmLNpIqe3ZtRcBgzP7j28V0-fSghl7ktfVLtlNr7ehBozmp-BLlbgZIW-CQdRswOuahN6wialeA/file [47874561/47874561] -> "test.zip" [1]
# 2022-06-16 07:53:02 URL:https://ucf5936ac7ac1cd276cd9fcea0d3.dl.dropboxusercontent.com/cd/0/inline2/BnQ_bM5i9_dcrkVNbajQZXxyYDq9727PiBius-XbNHpxTERmNG7Ce0fx6hRtlXLkGzj2eSGGnoGglc0XmtSLFkf70A1TlJW9BIV8p8DpT7oC1QmZH6Oz-ixd4jE47q25ld4UZFVY8b6lC40hCl4MvrwX-DoeP_5PYRsplOcAnNlMv8-mhjPEBel0St8guyhZOtk091wDO1t5Ra_PLs8JBJ69GAJsJwNXlH5ni7rMPRuwG3GXx_-CGPBN_QxvkFePBAGJ1LQt_0kPvNpRJLjUUvSWXC_hApYueHTFgPTFe1K8xb1Pz6nLlANwHRicsE_ftod6A6kFVfrvI_X6gfXwhfuReYvBULF3ua0BnfERFpILdG1n7eeC2yBXueNp2I2_fZ-JbKmJYMA572dsoKX1heHtCi_zTl9hxwwODaLdKwQrxQ/file [47378914/47378914] -> "val.zip" [1]

# %%
# !rm -rvf Training_Set_Pre
# !unzip -qq train.zip #-qq no verbose
# !unzip -qq test.zip
# !unzip -qq val.zip

# %%
#Método para crear estructura de directorios
def crearEstructura(nombreDataset, clases):
  # !mkdir "$nombreDataset"
  # !mkdir "$nombreDataset"/test
  # !mkdir "$nombreDataset"/train
  # !mkdir "$nombreDataset"/val
  for x in clases:
    # !mkdir "$nombreDataset"/train/"$x"
    # !mkdir "$nombreDataset"/test/"$x"
    # !mkdir "$nombreDataset"/val/"$x"

# %%
crearEstructura('dataset', ['normal', 'enfermedad'])

# %%
trainPath = Path('Training_Set_Pre/')
testPath  = Path('Test_Set_Pre/')
valPath  =  Path('Evaluation_Set_Pre/')

# %%
df_train = pd.read_csv(str(trainPath) + '/train.csv')
df_test = pd.read_csv(str(testPath) + '/test.csv')
df_val = pd.read_csv(str(valPath) + '/val.csv')

# %% [markdown]
# #### Mover imágenes:

# %%
import shutil

def moverImg(df, pathO, pathD):
  for id, enf in zip(df['ID'], df['Disease_Risk']):
    if(int(enf)==0):
        shutil.move(pathO + '/' + str(id) + '.png', pathD + '/normal')
    else:
        shutil.move(pathO + str(id) + '.png', pathD + '/enfermedad')

# %%
path = Path('dataset')

# %%
moverImg(df_train, str(trainPath) + '/Training/', str(path)  + '/train')
moverImg(df_test, str(testPath) + '/Test/', str(path)  + '/test')
moverImg(df_val, str(valPath) + '/Validation/', str(path)  + '/val')

# %% [markdown]
# ## Cargando el dataset

# %%
db = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=GrandparentSplitter(train_name='train', valid_name='val'),
                 get_y=parent_label,
                 item_tfms = Resize(256),
                 batch_tfms=aug_transforms(size=128,min_scale=0.75))

# %%
dls = db.dataloaders(path,bs=128)

# %%
dls.show_batch()

# %%
callbacks = [
    ShowGraphCallback(),
    EarlyStoppingCallback(patience=20),
    SaveModelCallback()  
]

# %%
learn = timm_learner(dls, 'inception_v3', metrics=[error_rate, accuracy], cbs=callbacks)
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-1a9a5a14.pth

# %%
learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(minimum=0.005754399299621582, steep=0.015848932787775993, valley=0.0020892962347716093, slide=0.013182567432522774)

# %% [markdown]
# ## Entrenamos el modelo

# %%
learn.fine_tune(60,base_lr=1e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.054570</td>
#       <td>0.788009</td>
#       <td>0.393750</td>
#       <td>0.606250</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.7880088686943054.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.651705</td>
#       <td>0.479896</td>
#       <td>0.189063</td>
#       <td>0.810938</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.594247</td>
#       <td>0.410436</td>
#       <td>0.192188</td>
#       <td>0.807813</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.563296</td>
#       <td>0.383045</td>
#       <td>0.176563</td>
#       <td>0.823438</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.547921</td>
#       <td>0.393518</td>
#       <td>0.175000</td>
#       <td>0.825000</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.508076</td>
#       <td>0.362057</td>
#       <td>0.156250</td>
#       <td>0.843750</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.477716</td>
#       <td>0.357540</td>
#       <td>0.157813</td>
#       <td>0.842188</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.463088</td>
#       <td>0.354163</td>
#       <td>0.154687</td>
#       <td>0.845312</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.442478</td>
#       <td>0.351795</td>
#       <td>0.148438</td>
#       <td>0.851562</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.426771</td>
#       <td>0.342524</td>
#       <td>0.171875</td>
#       <td>0.828125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.414373</td>
#       <td>0.351675</td>
#       <td>0.164062</td>
#       <td>0.835938</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.405156</td>
#       <td>0.363635</td>
#       <td>0.162500</td>
#       <td>0.837500</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.385588</td>
#       <td>0.354819</td>
#       <td>0.151562</td>
#       <td>0.848437</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.383510</td>
#       <td>0.309943</td>
#       <td>0.142188</td>
#       <td>0.857813</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.366772</td>
#       <td>0.301966</td>
#       <td>0.117188</td>
#       <td>0.882812</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.356099</td>
#       <td>0.305209</td>
#       <td>0.121875</td>
#       <td>0.878125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.341846</td>
#       <td>0.301370</td>
#       <td>0.121875</td>
#       <td>0.878125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.329043</td>
#       <td>0.303278</td>
#       <td>0.126563</td>
#       <td>0.873438</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.330962</td>
#       <td>0.305205</td>
#       <td>0.126563</td>
#       <td>0.873438</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.314820</td>
#       <td>0.423232</td>
#       <td>0.171875</td>
#       <td>0.828125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.298717</td>
#       <td>0.336600</td>
#       <td>0.134375</td>
#       <td>0.865625</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.293588</td>
#       <td>0.318892</td>
#       <td>0.123438</td>
#       <td>0.876562</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.273967</td>
#       <td>0.334797</td>
#       <td>0.121875</td>
#       <td>0.878125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.258390</td>
#       <td>0.387115</td>
#       <td>0.140625</td>
#       <td>0.859375</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.248760</td>
#       <td>0.357565</td>
#       <td>0.140625</td>
#       <td>0.859375</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.235930</td>
#       <td>0.363162</td>
#       <td>0.142188</td>
#       <td>0.857813</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.224203</td>
#       <td>0.359156</td>
#       <td>0.131250</td>
#       <td>0.868750</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.208712</td>
#       <td>0.364040</td>
#       <td>0.123438</td>
#       <td>0.876562</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.203804</td>
#       <td>0.392149</td>
#       <td>0.146875</td>
#       <td>0.853125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.200446</td>
#       <td>0.386680</td>
#       <td>0.150000</td>
#       <td>0.850000</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.193047</td>
#       <td>0.353802</td>
#       <td>0.134375</td>
#       <td>0.865625</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.183463</td>
#       <td>0.395699</td>
#       <td>0.129688</td>
#       <td>0.870313</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.178926</td>
#       <td>0.422928</td>
#       <td>0.121875</td>
#       <td>0.878125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.172987</td>
#       <td>0.357130</td>
#       <td>0.121875</td>
#       <td>0.878125</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.163967</td>
#       <td>0.445581</td>
#       <td>0.142188</td>
#       <td>0.857813</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.156839</td>
#       <td>0.490953</td>
#       <td>0.139062</td>
#       <td>0.860937</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.152398</td>
#       <td>0.419920</td>
#       <td>0.126563</td>
#       <td>0.873438</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.47989600896835327.
# Better model found at epoch 1 with valid_loss value: 0.4104364514350891.
# Better model found at epoch 2 with valid_loss value: 0.38304492831230164.
# Better model found at epoch 4 with valid_loss value: 0.36205658316612244.
# Better model found at epoch 5 with valid_loss value: 0.357540488243103.
# Better model found at epoch 6 with valid_loss value: 0.35416343808174133.
# Better model found at epoch 7 with valid_loss value: 0.351795494556427.
# Better model found at epoch 8 with valid_loss value: 0.3425242602825165.
# Better model found at epoch 12 with valid_loss value: 0.30994313955307007.
# Better model found at epoch 13 with valid_loss value: 0.3019658029079437.
# Better model found at epoch 15 with valid_loss value: 0.3013700544834137.
# No improvement since epoch 15: early stopping

# %%
learn.show_results(max_n=12, figsize=(7,8))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ## Evaluando el Modelo

# %%
dbTest = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=GrandparentSplitter(valid_name='test'),
                 get_y=parent_label,
                 item_tfms = Resize(256),
                 batch_tfms=aug_transforms(size=128,min_scale=0.75))
dlsTest = dbTest.dataloaders(path,bs=128)

# %%
learn.dls = dlsTest

# %% [markdown]
# Obtenemos una accuracy de 0.871.

# %%
learn.validate()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Better model found at epoch 0 with valid_loss value: 0.12812499701976776.
# (#3) [0.28880971670150757,0.12812499701976776,0.871874988079071]

# %% [markdown]
# Exportamos el modelo:

# %%
learn.to_fp32()
learn.export('modeloBinario_inception_v3.pkl')
